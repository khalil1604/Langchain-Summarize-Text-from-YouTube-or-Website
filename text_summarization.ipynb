# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
api_key=os.getenv("GROQ_API_KEY")
llm=ChatGroq(groq_api_key=api_key,model="Gemma-7b-It")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000015251F55880>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000015251F55970>, model_name='Gemma-7b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain.schema import(
    AIMessage,
    HumanMessage,SystemMessage
)

# %%
text = """
قد ترى يف ذلك ابتالء من اهلل عز ّ وجل، أم
ّ معارضوه فقد يرون يف ذلك عقابا له. وما ينطبق عىل املجال الفردي
ّ يمكن أن ينطبق أيضا عىل املجال اجلامعي ّ ، فالتسونامي ابتالء من 
منظور البعض وعقاب من منظور البعض اآلخر.
ّ إن ّ تأويل املصيبة يظل ّ دوما إمكانا ال يمكن القطع به، ذلك أن
ّكل ّ تأويل إذ يتحقق يفتح بالضرّ ّ ورة بتحققه بابا لتأويل آخر ممكن 
ّة امللتاعة 
ّ مل يتحق ّ ق، وبذلك فالتأويل ال يشفي غليل النّفس البرشي
))). ومن هنا يرتاوح النّ ّ اس بني الصرب يف حال 
ّ ظاهرا
وال يرحيها إال
ّ االقتناع بتأويلهم املمكن ملا أصاهبم من رش ّ وبني انحسار الصرب 
ّ واحلرية وتعم ّ ق األمل يف حال غياب التأويل القاطع النّهائي. وحينها 
ّ يرتفع ذلك السؤال النّ ّ ابع من األعامق املكلومة: »يا ريب عالش؟« 
ّ )ملاذا يا رب ّ ؟(. ذاك السؤال ال جواب هن ّ ائي ّ له، لذلك يظل األمل 
ّ قائام مهام تتعد ّ د األجوبة املمكنة. فليس أي منها سبيال إىل برد اليقني 
ّ ضا.
وطمأنينة ّ ضا حال يبلغها املرء بفضل من اهلل تعاىل، وهي حال تقوم 
الر
ّ ضا هي حال 
ّ عىل قبول كل ما حيصل بصفته ما جيب أن حيصل. الر
ّ ال توجد فيها إرادتان، إرادة الفرد وإرادة اهلل تعاىل، وإنام تذوب فيها 
ّ إرادة واحدة ال ثاين هلا.
إرادة الفرد يف إرادة اهلل، فال تبقى إال
ّ ّ ضا حال جتس ّ مها حكاية الش ّ يخ الذي ضاع ابنه فطلب منه 
الر
ّ بعض خال َ نه أن يدعو ّ اهلل تعاىل حت ّ ى يعود االبن، فأجاب: »إن
ّ رغبتي يف حتقق قضاء اهلل تعاىل يف ولدي أكرب من رغبتي يف عودته 
ّ إيل ّ «. ال يعني هذا اخلرب أن ّ الشيخ املذكور يريد األذى البنه، وال يعني 
ّ أن االبن لن يعود، ولكنّ ٌ ه خرب يبينّ مدى قدرة بعض النّاس عىل أن 
ّ تكون إرادهتم اخلاص ّ ة هي فحسب حتقق إرادة اهلل تعاىل فيهم. وهذا 
ُسنَ ّ د إىل عمر بن اخلط ّ اب من أن ّ ه قال: »ما أبايل عىل أي حال 
شبيه بام ي
ّ أصبحت عىل ما أحب أو عىل ما أكره، ألنيّ ّ ال أدري اخلري فيام أحب

"""

# %%
text
# Out:
# '\nقد ترى يف ذلك ابتالء من اهلل عز ّ وجل، أم\nّ معارضوه فقد يرون يف ذلك عقابا له. وما ينطبق عىل املجال الفردي\nّ يمكن أن ينطبق أيضا عىل املجال اجلامعي ّ ، فالتسونامي ابتالء من \nمنظور البعض وعقاب من منظور البعض اآلخر.\nّ إن ّ تأويل املصيبة يظل ّ دوما إمكانا ال يمكن القطع به، ذلك أن\nّكل ّ تأويل إذ يتحقق يفتح بالضرّ ّ ورة بتحققه بابا لتأويل آخر ممكن \nّة امللتاعة \nّ مل يتحق ّ ق، وبذلك فالتأويل ال يشفي غليل النّفس البرشي\n))). ومن هنا يرتاوح النّ ّ اس بني الصرب يف حال \nّ ظاهرا\nوال يرحيها إال\nّ االقتناع بتأويلهم املمكن ملا أصاهبم من رش ّ وبني انحسار الصرب \nّ واحلرية وتعم ّ ق األمل يف حال غياب التأويل القاطع النّهائي. وحينها \nّ يرتفع ذلك السؤال النّ ّ ابع من األعامق املكلومة: »يا ريب عالش؟« \nّ )ملاذا يا رب ّ ؟(. ذاك السؤال ال جواب هن ّ ائي ّ له، لذلك يظل األمل \nّ قائام مهام تتعد ّ د األجوبة املمكنة. فليس أي منها سبيال إىل برد اليقني \nّ ضا.\nوطمأنينة ّ ضا حال يبلغها املرء بفضل من اهلل تعاىل، وهي حال تقوم \nالر\nّ ضا هي حال \nّ عىل قبول كل ما حيصل بصفته ما جيب أن حيصل. الر\nّ ال ت
# ...

# %%
chat_message=[
    SystemMessage(content="You are expert with experise in summarizing speeched"),
    HumanMessage(content=f"Please provide a short and concisse summary of the follow speech:\n Text:{text}")
]

# %%
llm.get_num_tokens(text)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1729 > 1024). Running this sequence through the model will result in indexing errors
# 1729

# %%
## getting the summary
llm(chat_message)
# Out:
# AIMessage(content='**Summary:**\n\nThe speaker emphasizes the importance of adhering to principles and values, regardless of individual or collective desires. He argues that meaningful change can only occur when individuals prioritize integrity and commitments. The speaker uses the parable of a father who refuses to compromise his principles for his son, highlighting the power of unwavering integrity. He concludes by urging listeners to embrace values and commitments wholeheartedly, even when faced with challenges.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 817, 'total_tokens': 899, 'completion_time': 0.111946686, 'prompt_time': 0.678605364, 'queue_time': 0.0010826949999999114, 'total_time': 0.79055205}, 'model_name': 'Gemma-7b-It', 'system_fingerprint': 'fp_7d8efeb0b1', 'finish_reason': 'stop', 'logprobs': None}, id='run-db0eac62-e500-486a-bbd8-b31313b1fc9b-0', usage_metadata={'input_tokens': 817, 'output_tokens': 82, 'total_
# ...

# %% [markdown]
# ## Prompt Template Text Summarization

# %%
from langchain.chains import LLMChain
from langchain import PromptTemplate

generictemplate="""
Write a summary of the following speech:
Speech:{text}
Translate the precise summary to {language}
"""

prompt=PromptTemplate(
    input_variables=['text','language'],
    template=generictemplate
)
prompt
# Out:
# PromptTemplate(input_variables=['language', 'text'], input_types={}, partial_variables={}, template='\nWrite a summary of the following speech:\nSpeech:{text}\nTranslate the precise summary to {language}\n')

# %%
complete_prompt=prompt.format(text=text,language="French")
complete_prompt
# Out:
# '\nWrite a summary of the following speech:\nSpeech:\nقد ترى يف ذلك ابتالء من اهلل عز ّ وجل، أم\nّ معارضوه فقد يرون يف ذلك عقابا له. وما ينطبق عىل املجال الفردي\nّ يمكن أن ينطبق أيضا عىل املجال اجلامعي ّ ، فالتسونامي ابتالء من \nمنظور البعض وعقاب من منظور البعض اآلخر.\nّ إن ّ تأويل املصيبة يظل ّ دوما إمكانا ال يمكن القطع به، ذلك أن\nّكل ّ تأويل إذ يتحقق يفتح بالضرّ ّ ورة بتحققه بابا لتأويل آخر ممكن \nّة امللتاعة \nّ مل يتحق ّ ق، وبذلك فالتأويل ال يشفي غليل النّفس البرشي\n))). ومن هنا يرتاوح النّ ّ اس بني الصرب يف حال \nّ ظاهرا\nوال يرحيها إال\nّ االقتناع بتأويلهم املمكن ملا أصاهبم من رش ّ وبني انحسار الصرب \nّ واحلرية وتعم ّ ق األمل يف حال غياب التأويل القاطع النّهائي. وحينها \nّ يرتفع ذلك السؤال النّ ّ ابع من األعامق املكلومة: »يا ريب عالش؟« \nّ )ملاذا يا رب ّ ؟(. ذاك السؤال ال جواب هن ّ ائي ّ له، لذلك يظل األمل \nّ قائام مهام تتعد ّ د األجوبة املمكنة. فليس أي منها سبيال إىل برد اليقني \nّ ضا.\nوطمأنينة ّ ضا حال يبلغها املرء بفضل من اهلل تعاىل، وهي حال تقوم \nالر\nّ ضا هي حال \nّ عى
# ...

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
summary=llm_chain.run({'text':text,'language':'spanish'})
summary
# Out:
# '**Resumen:**\n\nEl orador enfatiza la importancia de tomar decisiones y aceptar los resultados. Afirma que las decisiones tienen consecuencias tanto positivas como negativas.\n\nTambién destaca la necesidad de tomar decisiones en conjunto, considerando las perspectivas de todos los involucrados. Sin embargo, advierte que a veces es necesario tomar decisiones sin el consentimiento de los demás.\n\nFinalmente, el orador anima a la gente a tomar decisiones y aceptar los resultados, independientemente de los sentimientos y las expectativas de los demás.\n\n**Traducción al español:**\n\nEn este discurso, el orador enfatiza la importancia de tomar decisiones y aceptar las consecuencias. Afirma que las decisiones tienen consecuencias tanto positivas como negativas.\n\nTambién enfatiza la importancia de tomar decisiones en conjunto, considerando las perspectivas de todos los involucrados. Sin embargo, advierte que a veces es necesario tomar decisiones sin el consentimiento de los demás.\n\n
# ...

# %% [markdown]
# ## StuffDocumentChain Text summarization

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("apjspeech.pdf")
docs = loader.load_and_split()
docs
# Out:
# [Document(metadata={'source': 'apjspeech.pdf', 'page': 0}, page_content='A P J Abdul Kalam Departing speech \n \n \nFriends, I am delighted to address you all, in the country and those livi ng abroad, after \nworking with you and completing five beautiful and eventful years in Rashtrapati \nBhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I \nenjoyed every minute of my tenure enriched by the wonderful assoc iation from each one \nof you, hailing from different walks of life, be it politics, sci ence and technology, \nacademics, arts, literature, business, judiciary, administration, local bodies, farming, \nhome makers, special children, media and above all from the youth and st udent \ncommunity who are the future wealth of our country. During my intera ction at \nRashtrapati Bhavan in Delhi and at every state and union territor y as well as through my \nonline interactions, I have many unique experiences to share with you, which signify the \nfollo
# ...

# %%
template=""" Write a concise and short summary of the following speech,
Speech :{text}

 """
prompt=PromptTemplate(input_variables=['text'],
                      template=template)

# %%
from langchain.chains.summarize import load_summarize_chain

# %%
chain=load_summarize_chain(llm,chain_type='stuff',prompt=prompt,verbose=True)
output_summary=chain.run(docs)
output_summary
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Prompt after formatting:
#  Write a concise and short summary of the following speech,
# Speech :A P J Abdul Kalam Departing speech
#
#
# Friends, I am delighted to address you all, in the country and those livi ng abroad, after
# working with you and completing five beautiful and eventful years in Rashtrapati
# Bhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I
# enjoyed every minute of my tenure enriched by the wonderful assoc iation from each one
# of you, hailing from different walks of life, be it politics, sci ence and technology,
# academics, arts, literature, business, judiciary, administration, local bodies, farming,
# home makers, special children, media and above all from the youth and st udent
# ...

# %% [markdown]
# ## Map reduce to Summarize Large documents

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
docs
# Out:
# [Document(metadata={'source': 'apjspeech.pdf', 'page': 0}, page_content='A P J Abdul Kalam Departing speech \n \n \nFriends, I am delighted to address you all, in the country and those livi ng abroad, after \nworking with you and completing five beautiful and eventful years in Rashtrapati \nBhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I \nenjoyed every minute of my tenure enriched by the wonderful assoc iation from each one \nof you, hailing from different walks of life, be it politics, sci ence and technology, \nacademics, arts, literature, business, judiciary, administration, local bodies, farming, \nhome makers, special children, media and above all from the youth and st udent \ncommunity who are the future wealth of our country. During my intera ction at \nRashtrapati Bhavan in Delhi and at every state and union territor y as well as through my \nonline interactions, I have many unique experiences to share with you, which signify the \nfollo
# ...

# %%
final_documents=RecursiveCharacterTextSplitter(chunk_size=2000,chunk_overlap=100).split_documents(docs)
final_documents
# Out:
# [Document(metadata={'source': 'apjspeech.pdf', 'page': 0}, page_content='A P J Abdul Kalam Departing speech \n \n \nFriends, I am delighted to address you all, in the country and those livi ng abroad, after \nworking with you and completing five beautiful and eventful years in Rashtrapati \nBhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I \nenjoyed every minute of my tenure enriched by the wonderful assoc iation from each one \nof you, hailing from different walks of life, be it politics, sci ence and technology, \nacademics, arts, literature, business, judiciary, administration, local bodies, farming, \nhome makers, special children, media and above all from the youth and st udent \ncommunity who are the future wealth of our country. During my intera ction at \nRashtrapati Bhavan in Delhi and at every state and union territor y as well as through my \nonline interactions, I have many unique experiences to share with you, which signify the \nfollo
# ...

# %%
len(final_documents)
# Out:
# 13

# %%
chunks_prompt="""
Please summarize the below speech:
Speech:`{text}'
Summary:
"""
map_prompt_template=PromptTemplate(input_variables=['text'],
                                    template=chunks_prompt)

# %%
final_prompt='''
Provide the final summary of the entire speech with these important points.
Add a Motivation Title,Start the precise summary with an introduction and provide the summary in number 
points for the speech.
Speech:{text}

'''
final_prompt_template=PromptTemplate(input_variables=['text'],template=final_prompt)
final_prompt_template
# Out:
# PromptTemplate(input_variables=['text'], input_types={}, partial_variables={}, template='\nProvide the final summary of the entire speech with these important points.\nAdd a Motivation Title,Start the precise summary with an introduction and provide the summary in number \npoints for the speech.\nSpeech:{text}\n\n')

# %%
summary_chain=load_summarize_chain(
    llm=llm,
    chain_type="map_reduce",
    map_prompt=map_prompt_template,
    combine_prompt=final_prompt_template,
    verbose=True
)

output=summary_chain.run(final_documents)
output
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Prompt after formatting:
#
# Please summarize the below speech:
# Speech:`A P J Abdul Kalam Departing speech
#
#
# Friends, I am delighted to address you all, in the country and those livi ng abroad, after
# working with you and completing five beautiful and eventful years in Rashtrapati
# Bhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I
# enjoyed every minute of my tenure enriched by the wonderful assoc iation from each one
# of you, hailing from different walks of life, be it politics, sci ence and technology,
# academics, arts, literature, business, judiciary, administration, local bodies, farming,
# home makers, special children, media and above all from the youth and st udent
# ...

# %% [markdown]
# ## Refine Chain For Summarization

# %%
chain=load_summarize_chain(
    llm=llm,
    chain_type="refine",
    verbose=True
)
output_summary=chain.run(final_documents)
output_summary
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "A P J Abdul Kalam Departing speech
#
#
# Friends, I am delighted to address you all, in the country and those livi ng abroad, after
# working with you and completing five beautiful and eventful years in Rashtrapati
# Bhavan. Today, it is indeed a thanks giving occasion. I would like to narr ate, how I
# enjoyed every minute of my tenure enriched by the wonderful assoc iation from each one
# of you, hailing from different walks of life, be it politics, sci ence and technology,
# academics, arts, literature, business, judiciary, administration, local bodies, farming,
# home makers, special children, media and above all from the youth and st udent
# ...
